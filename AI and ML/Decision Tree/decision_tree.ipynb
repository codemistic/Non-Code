# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from matplotlib import pyplot as plt
from sklearn.tree import plot_tree
# Out:
# Running cells with 'Python 3.10.6 64-bit (microsoft store)' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/prank/AppData/Local/Microsoft/WindowsApps/python3.10.exe -m pip install ipykernel -U --force-reinstall'

# %%
iris = load_iris()

# %%
data = pd.DataFrame(iris.data,columns=iris.feature_names)
data.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
data['species']=pd.DataFrame(iris.target)
data
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      species
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ..       ...
# 145        2
# 146        2
# 147        2
# 148        2
# 149        2
#
# [150 rows x 5 columns]

# %%
x=data.iloc[:,:-1]
y=data.iloc[:,-1]

xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.3)
model = DecisionTreeClassifier(criterion="entropy",splitter='best')

# %%
model_fit=model.fit(xtrain,ytrain)
ypredict=model.predict(xtest)

# %%
print(accuracy_score(ypredict,ytest).round(2)*100)
# Out:
# 98.0

# %%
# %matplotlib inline 
plt.figure(figsize=(30,10))
plot_tree(model_fit,
            feature_names=iris.feature_names,
            class_names=iris.target_names,
            filled=True)
plt.show()
