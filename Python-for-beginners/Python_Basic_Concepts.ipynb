# %% [markdown]
# SDLC - Waterfall model has stages as follows:
# - customer requirement
# - analysis
# - design
# - implementation
# - integration
# - maintenance

# %%
"""Hello
world"""
# Out:
# 'Hello\nworld'

# %%
print("Hello
world")
#Note that the first line in the output ends exactly where the first line ends in the code.
#use triple quotes for long strings

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Docstrings** is generally in the beginning of the program with """ """ and **end line comments** are with #.

# %% [markdown]
# Also, three common **syntax errors** in python include:
# unexpected indent,
# invalid syntax and
# name 'lenth' is not defined

# %%
print(print(print(print("Hello"))))
# Out:
# Hello
# None
# None
# None

# %% [markdown]
# However, the magnitude of a Python
# **integer** is much larger and is **limited only by the memory** of your computer.Values of the most common implementation of Python’s **float** type range from
# approximately -10^308 to 10^308 and have **16** digits of precision.

# %% [markdown]
# **Python, character literals look just like string literals and are of the string type**
#
# 1.   65-90 : A-Z
# 2.   97-122 : a-z
#
# Python’s **ord and chr** functions convert characters to their numeric ASCII codes and back again, respectively

# %% [markdown]
# The **precedence rules** you learned in algebra apply during the evaluation of arithmetic
# expressions in Python:
# - Exponentiation has the highest precedence and is evaluated first.
# - Unary negation is evaluated next, before multiplication, division, and remainder.
# - Multiplication, both types of division, and remainder are evaluated before addition and
# subtraction.
# - Addition and subtraction are evaluated before assignment.
# - With two exceptions, operations of equal precedence are left associative, so they are
# evaluated from left to right. Exponentiation and assignment operations are right associative, so consecutive instances of these are evaluated from right to left.
# - You can use parentheses to change the order of evaluation

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
(-3)**2
# Out:
# 9

# %%
-10//4  #floor division with negative numbers
# Out:
# -3

# %% [markdown]
#  **Syntax** is the set of rules for constructing well-formed expressions or sentences in a language.
# **Semantics** is the set of rules that allow an agent to interpret the meaning of those expressions or sentences. A computer generates a syntax error when an expression or sentence is
# not well formed. A semantic error is detected when the action that an expression describes
# cannot be carried out, even though that expression is syntactically correct. Although the
# expressions 45 / 0 and 45 % 0 are syntactically correct, they are meaningless, because a
# computing agent cannot carry them out.

# %% [markdown]
# Normally, an expression must be completed on a single line of
# Python code. When an **expression becomes long or complex**, you can move to a new line by placing a backslash character \ at the end of the current line. The next example shows
# this technique. Make sure to insert the backslash before or after an **operator**

# %%
 3 + 4 * \
2 ** 5
# Out:
# 131

# %% [markdown]
# **Mixed mode arithmetic** - when one or more data types are involved in a single expression.

# %% [markdown]
# **Note** that the int function converts a float to an int by truncation, not by rounding to the
# nearest whole number. Truncation simply chops off the number’s fractional part. The round
# function rounds a float to the nearest int as in the next example:

# %%
int(6.75)
# Out:
# 6

# %%
round(6.75)
# Out:
# 7

# %%
import math
print(math.ceil(6.75))
print(math.floor(6.75))
# Out:
# 7
# 6

# %% [markdown]
# Python is a **strongly typed programming language**. The interpreter checks data types of
# all operands before operators are applied to those operands. If the type of an operand is not
# appropriate, the interpreter halts execution with an error message. This error checking prevents a program from attempting to do something that it cannot do.

# %%
profit = 1000.55
print('$' + profit) #cant concatenate string and float but we can use comma or type conversion

# %% [markdown]
# Python includes many useful functions, which are organized
# in libraries of code called **modules**.Functions and other resources are coded in components called modules. Functions like
# abs and round from the `__builtin__` module are always available for use, whereas the
# programmer must explicitly import other functions from the modules where they are
# defined.

# %% [markdown]
# round(7.563, 2) returns 7.56. here first one is a **required argument** and the second one is an **optional** one.

# %% [markdown]
# Three ways of **importing from math:**
# - import math
# - from math import *
# - from math import pi, sqrt

# %% [markdown]
# ---

# %% [markdown]
# The first line of code in a loop is sometimes called the **loop header**. For now, the only relevant information in the header is the integer expression, which denotes the number of
# iterations that the loop performs. The colon (:) ends the loop header. The **loop body** comprises the statements in the remaining lines of code, below the header. These statements are
# executed in sequence on each pass through the loop. Note that the statements in the loop
# body must be indented and aligned in the same column. Loops that count through a range of numbers are also called **count-controlled loops**.

# %% [markdown]
# **Note** that we use the variable theSum rather than sum to accumulate the sum of the numbers
# in this code. Since sum is the name of a built-in Python function, it’s a good idea to avoid
# using such names for other purposes in our code.

# %% [markdown]
# The assignment symbol can be combined with the
# arithmetic and concatenation operators to provide **augmented assignment operations**. Eg - x = x + 2 can be written as x += 2

# %% [markdown]
# **Off by one error** is a very common python **logical** error where the programmer specifies the upper bound incorrectly and thus the loop fails to perform the required number of iterations.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# When the step argument is a negative number, the range function generates a sequence
# of numbers from the first argument down to the second argument plus 1. Thus, in this
# case, the first argument should express the upper bound, and the second argument should
# express the lower bound minus 1.

# %% [markdown]
# The total number of data characters and additional spaces for a given datum in a formatted
# string is called its **field width**. When the field width is positive, the datum is
# right-justified; when the field width is negative, you get left-justification. To format integers, you use the letter d instead of s.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ```
# <format string> % <datum>
# %<field width>s is used in format string
# ```

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **The comparison operators are applied after addition but before assignment.**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# The logical operators are evaluated after
# comparisons but before the assignment operator. The not operator has a higher precedence
# than the and operator, which has a higher precedence than the or operator

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# The approach, in which evaluation stops as soon as possible, is called
# **short-circuit evaluation**

# %% [markdown]
# For example, the user might be asked for a set of input values. In that case,
# only the user knows the number she will enter. The program’s input loop accepts these values until the user enters a special value or **sentinel** that terminates the input. This type of
# process is called conditional iteration, meaning that the process continues to repeat as long
# as a condition remains **true**. In this section, we explore the use of the while loop to describe
# conditional iteration.(Continuation condition - loop control variable)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# The string is an **immutable data structure**. This means that its internal data elements, the characters, can be accessed, but cannot be replaced, inserted, or removed.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
